# %%
import pandas as pd

# %%
fLog = pd.read_csv('/Users/jordangalida/Desktop/School2019/IST451/Lab8/csv/20110413_VAST11MC2_firewall_log_1.csv')

# %%
fLog.head()
# Out:
#               Date/time Syslog priority Operation          Message code  \
# 0  13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 1  13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 2  13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 3  13/Apr/2011 08:52:52            Info  Teardown  ASA-session-6-302014
# 4  13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
#
#   Protocol      Source IP Destination IP Source hostname Destination hostname  \
# 0      TCP  192.168.2.133    192.168.1.6         (empty)              (empty)
# 1      TCP  192.168.2.133    192.168.1.6         (empty)              (empty)
# 2      TCP  192.168.2.133    192.168.1.6         (empty)              (empty)
# 3      TCP  192.168.2.133    192.168.1.6         (empty)              (empty)
# 4      TCP  192.168.2.133    192.168.1.6         (empty)              (empty)
#
#   Source port Destination port Destination service Direction  \
# ...

# %%
fLog[fLog['Source IP'] == '192.168.2.133']
# Out:
#                     Date/time Syslog priority Operation          Message code  \
# 0        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 1        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 2        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 3        13/Apr/2011 08:52:52            Info  Teardown  ASA-session-6-302014
# 4        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 5        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 6        13/Apr/2011 08:52:53            Info  Teardown  ASA-session-6-302014
# 7        13/Apr/2011 08:52:53            Info  Teardown  ASA-session-6-302014
# 126      13/Apr/2011 08:53:04            Info  Teardown  ASA-session-6-302014
# 127      13/Apr/2011 08:53:04            Info  Teardown  ASA-session-6-302014
# 128      13/Apr/2011 08:53:04            Info  Teardown  ASA-session-6-302014
# ...

# %%
from collections import Counter

# %%
from numpy import nan as NA

# %%
fLog['Source IP'].value_counts()
# Out:
# 10.200.150.206    486719
# 10.200.150.209    473284
# 10.200.150.201    470965
# 10.200.150.207    422928
# 10.200.150.208    359142
# 192.168.1.6        46809
# (empty)            10369
# 192.168.1.2         2211
# 192.168.1.14        2056
# 192.168.2.46        1890
# 192.168.2.98        1610
# 192.168.2.64        1350
# 192.168.2.137       1272
# 192.168.2.95        1251
# 192.168.2.14        1193
# 192.168.2.121       1182
# 192.168.2.71        1169
# 192.168.2.61        1154
# 192.168.2.34        1121
# 192.168.2.97         998
# 192.168.2.127        937
# 192.168.2.85         798
# 192.168.2.106        747
# 192.168.2.11         687
# 192.168.2.96         685
# 192.168.2.138        596
# 192.168.2.13         560
# 192.168.2.156        557
# 192.168.2.16         557
# 192.168.2.90         555
#                    ...
# 192.168.2.148        156
# 192.168.2.58         154
# 192.168.2.151        149
# 192.168.2.145        146
# 192.168.2.173        144
# 192.168.2.93         138
# ...

# %%
df = fLog['Source IP'][fLog['Source IP'] ==  '172.20.1.5']

# %%
df.value_counts()
# Out:
# 172.20.1.5    93
# Name: Source IP, dtype: int64

# %%
df
# Out:
#                     Date/time Syslog priority Operation          Message code  \
# 443      13/Apr/2011 08:53:32            Info     Built  ASA-session-6-302015
# 444      13/Apr/2011 08:53:32            Info     Built  ASA-session-6-302013
# 576      13/Apr/2011 08:53:43            Info  Teardown  ASA-session-6-302014
# 2747     13/Apr/2011 08:55:33            Info  Teardown  ASA-session-6-302016
# 8282     13/Apr/2011 09:00:40            Info     Built  ASA-session-6-302015
# 10213    13/Apr/2011 09:02:42            Info  Teardown  ASA-session-6-302016
# 13785    13/Apr/2011 09:05:59            Info     Built  ASA-session-6-302015
# 15808    13/Apr/2011 09:08:00            Info  Teardown  ASA-session-6-302016
# 16548    13/Apr/2011 09:08:32            Info     Built  ASA-session-6-302013
# 16696    13/Apr/2011 09:08:43            Info  Teardown  ASA-session-6-302014
# 32416    13/Apr/2011 09:23:32            Info     Built  ASA-session-6-302013
# ...

# %%
fLog[fLog['Destination port'] == '88']
# Out:
#                     Date/time Syslog priority Operation          Message code  \
# 184      13/Apr/2011 08:53:16            Info  Teardown  ASA-session-6-302016
# 186      13/Apr/2011 08:53:16            Info  Teardown  ASA-session-6-302016
# 209      13/Apr/2011 08:53:17            Info  Teardown  ASA-session-6-302016
# 210      13/Apr/2011 08:53:17            Info  Teardown  ASA-session-6-302016
# 211      13/Apr/2011 08:53:17            Info  Teardown  ASA-session-6-302016
# 212      13/Apr/2011 08:53:17            Info  Teardown  ASA-session-6-302016
# 314      13/Apr/2011 08:53:25            Info  Teardown  ASA-session-6-302016
# 315      13/Apr/2011 08:53:25            Info  Teardown  ASA-session-6-302016
# 317      13/Apr/2011 08:53:25            Info  Teardown  ASA-session-6-302016
# 318      13/Apr/2011 08:53:25            Info  Teardown  ASA-session-6-302016
# 354      13/Apr/2011 08:53:27            Info     Built  ASA-session-6-302015
# ...

# %%
df = fLog[['Source IP', 'Destination port']][(fLog['Source IP'] ==  '172.20.1.5')&(fLog['Destination port'] == '88')]

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df
# Out:
#          Source IP Destination port
# 61942   172.20.1.5               88
# 61945   172.20.1.5               88
# 61946   172.20.1.5               88
# 61947   172.20.1.5               88
# 111535  172.20.1.5               88
# 111538  172.20.1.5               88
# 111539  172.20.1.5               88
# 111540  172.20.1.5               88

# %%
df['Source IP']
# Out:
# 61942     172.20.1.5
# 61945     172.20.1.5
# 61946     172.20.1.5
# 61947     172.20.1.5
# 111535    172.20.1.5
# 111538    172.20.1.5
# 111539    172.20.1.5
# 111540    172.20.1.5
# Name: Source IP, dtype: object

# %%
# Out:
#          Source IP Destination port
# 61942   172.20.1.5               88
# 61945   172.20.1.5               88
# 61946   172.20.1.5               88
# 61947   172.20.1.5               88
# 111535  172.20.1.5               88
# 111538  172.20.1.5               88
# 111539  172.20.1.5               88
# 111540  172.20.1.5               88 8

# %%
df = fLog[['Source IP', 'Destination port']][(fLog['Source IP'] ==  '172.20.1.5')&(fLog['Destination port'] == '80')]

# %%
len(df)
# Out:
# 0

# %%
 fLog = pd.read_csv('/Users/jordangalida/Desktop/School2019/IST451/Lab8/csv/20110413_VAST11MC2_firewall_log_1.csv')
 
 fLog1 = pd.read_csv('/Users/jordangalida/Desktop/School2019/IST451/Lab8/csv/20110413_VAST11MC2_firewall_log_2.csv')
 
 fLog2 = pd.read_csv('/Users/jordangalida/Desktop/School2019/IST451/Lab8/csv/20110413_VAST11MC2_firewall_log_3.csv')
 
 fLog3 = pd.read_csv('/Users/jordangalida/Desktop/School2019/IST451/Lab8/csv/20110413_VAST11MC2_firewall_log_4.csv')
 
 fLog4 = pd.read_csv('/Users/jordangalida/Desktop/School2019/IST451/Lab8/csv/20110413_VAST11MC2_firewall_log_5.csv')
 
 concat = pd.concat([fLog,fLog1,fLog2,fLog3,fLog4])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
concat.shape
# Out:
# (10452110, 15)

# %%
df = concat['Source IP'][concat['Source IP'] ==  '172.20.1.5']

# %%
df.value_counts()
# Out:
# 172.20.1.5    793
# Name: Source IP, dtype: int64

# %%
df = concat[['Source IP', 'Destination port']][(concat['Source IP'] ==  '172.20.1.5')&(concat['Destination port'] == '80')]

# %%
len(df)
# Out:
# 0

# %%
concat[concat['Destination IP'] == '80']
# Out:
# Empty DataFrame
# Columns: [Date/time, Syslog priority, Operation, Message code, Protocol, Source IP, Destination IP, Source hostname, Destination hostname, Source port, Destination port, Destination service, Direction, Connections built, Connections torn down]
# Index: []

# %%
concat.columns.tolist()
# Out:
# ['Date/time',
#  'Syslog priority',
#  'Operation',
#  'Message code',
#  'Protocol',
#  'Source IP',
#  'Destination IP',
#  'Source hostname',
#  'Destination hostname',
#  'Source port',
#  'Destination port',
#  'Destination service',
#  'Direction',
#  'Connections built',
#  'Connections torn down']

# %%
concat['Date/time']
# Out:
# 0          13/Apr/2011 08:52:52
# 1          13/Apr/2011 08:52:52
# 2          13/Apr/2011 08:52:52
# 3          13/Apr/2011 08:52:52
# 4          13/Apr/2011 08:52:52
# 5          13/Apr/2011 08:52:52
# 6          13/Apr/2011 08:52:53
# 7          13/Apr/2011 08:52:53
# 8          13/Apr/2011 08:52:53
# 9          13/Apr/2011 08:52:53
# 10         13/Apr/2011 08:52:53
# 11         13/Apr/2011 08:52:53
# 12         13/Apr/2011 08:52:55
# 13         13/Apr/2011 08:52:55
# 14         13/Apr/2011 08:52:55
# 15         13/Apr/2011 08:52:55
# 16         13/Apr/2011 08:52:55
# 17         13/Apr/2011 08:52:55
# 18         13/Apr/2011 08:52:55
# 19         13/Apr/2011 08:52:55
# 20         13/Apr/2011 08:52:55
# 21         13/Apr/2011 08:52:55
# 22         13/Apr/2011 08:52:56
# 23         13/Apr/2011 08:52:56
# 24         13/Apr/2011 08:52:56
# 25         13/Apr/2011 08:52:56
# 26         13/Apr/2011 08:52:56
# 27         13/Apr/2011 08:52:56
# 28         13/Apr/2011 08:52:56
# ...

# %%
concat.dropna()
# Out:
#                     Date/time Syslog priority Operation          Message code  \
# 0        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 1        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 2        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 3        13/Apr/2011 08:52:52            Info  Teardown  ASA-session-6-302014
# 4        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 5        13/Apr/2011 08:52:52            Info     Built  ASA-session-6-302013
# 6        13/Apr/2011 08:52:53            Info  Teardown  ASA-session-6-302014
# 7        13/Apr/2011 08:52:53            Info  Teardown  ASA-session-6-302014
# 8        13/Apr/2011 08:52:53            Info  Teardown  ASA-session-6-302014
# 9        13/Apr/2011 08:52:53            Info  Teardown  ASA-session-6-302014
# 10       13/Apr/2011 08:52:53            Info  Teardown  ASA-session-6-302014
# ...

# %%
fIP = concat[['Date/time','Source IP']][concat['Source IP'] == '172.20.1.5']

# %%
fIP
# Out:
#                     Date/time   Source IP
# 443      13/Apr/2011 08:53:32  172.20.1.5
# 444      13/Apr/2011 08:53:32  172.20.1.5
# 576      13/Apr/2011 08:53:43  172.20.1.5
# 2747     13/Apr/2011 08:55:33  172.20.1.5
# 8282     13/Apr/2011 09:00:40  172.20.1.5
# 10213    13/Apr/2011 09:02:42  172.20.1.5
# 13785    13/Apr/2011 09:05:59  172.20.1.5
# 15808    13/Apr/2011 09:08:00  172.20.1.5
# 16548    13/Apr/2011 09:08:32  172.20.1.5
# 16696    13/Apr/2011 09:08:43  172.20.1.5
# 32416    13/Apr/2011 09:23:32  172.20.1.5
# 32540    13/Apr/2011 09:23:43  172.20.1.5
# 48052    13/Apr/2011 09:38:32  172.20.1.5
# 48450    13/Apr/2011 09:38:43  172.20.1.5
# 61907    13/Apr/2011 09:46:50  172.20.1.5
# 61909    13/Apr/2011 09:46:50  172.20.1.5
# 61910    13/Apr/2011 09:46:50  172.20.1.5
# 61912    13/Apr/2011 09:46:50  172.20.1.5
# 61913    13/Apr/2011 09:46:50  172.20.1.5
# 61939    13/Apr/2011 09:46:53  172.20.1.5
# 61940    13/Apr/2011 09:46:53  172.20.1.5
# ...

# %%
len(fIP) - fIP.nunique()
# Out:
# Date/time    352
# Source IP    792
# dtype: int64

# %%
concat['Date/time'] = pd.to_datetime(concat['Date/time'])

# %%
fIP['Date/time'] = pd.to_datetime(fIP['Date/time'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-898ff7609680> in <module>
# ----> 1 fIP['Date/time'] = pd.to_datetime(fIP['Date/time'])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     590         else:
#     591             from pandas import Series
# --> 592             values = convert_listlike(arg._values, True, format)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
#
# ...

# %%
times = pd.to_datetime(fIP.timestamp_col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-25846b3998f1> in <module>
# ----> 1 times = pd.to_datetime(fIP.timestamp_col)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'timestamp_col'

# %%
type(concat['Date/time'])
# Out:
# pandas.core.series.Series

# %%
fIP.pivot_table(index='Date/time', columns='Source IP', aggfunc='size').rename_axis(None, axis=1)
# Out:
#            172.20.1.5
# Date/time
# 00:00:05            1
# 00:08:35            1
# 00:08:48            1
# 00:23:35            6
# 00:23:48            1
# 00:25:37            1
# 00:38:35            3
# 00:38:48            1
# 00:53:35            2
# 00:53:48            1
# 00:55:37            1
# 01:07:02            1
# 01:07:05            1
# 01:08:35            1
# 01:08:48            1
# 01:09:07            2
# 01:10:25            3
# 01:10:26            2
# 01:10:28           15
# 01:10:40            1
# 01:10:53            1
# 01:12:00            1
# 01:12:27            3
# 01:12:29            2
# 01:23:35            1
# 01:23:48            1
# 01:38:36            1
# 01:38:48            1
# 01:51:03            1
# 01:53:05            1
# ...               ...
# 22:38:46            1
# 22:53:35            2
# 22:53:46            1
# 22:55:36            1
# 23:06:58            1
# 23:07:02            1
# 23:08:35            1
# 23:08:47            1
# 23:09:03            2
# ...

# %%
fIP['Date/time'] = pd.to_datetime(fIP['Date/time'], errors='coerce').dt.time

# %%
fIP = concat[['Date/time','Source IP']][concat['Source IP'] == '172.20.1.5']

# %%
concat['Date/time']=pd.to_datetime(concat['Date/time'])

# %%
concat.pivot_table(index=pd.Grouper(freq='H', key='Date/time'),columns='Source IP')
# Out:
#                     Connections built                              \
# Source IP                     (empty) 10.200.150.2 10.200.150.201
# Date/time
# 2011-04-13 08:00:00          0.478814     0.333333            NaN
# 2011-04-13 09:00:00          0.469044     0.363636            NaN
# 2011-04-13 10:00:00          0.486111     0.323077            NaN
# 2011-04-13 11:00:00          0.498044     0.363636       0.563880
# 2011-04-13 12:00:00          0.503505     0.315789       0.567114
# 2011-04-13 13:00:00          0.499432     0.425532            NaN
# 2011-04-13 14:00:00          0.498143     0.206349            NaN
# 2011-04-13 15:00:00          0.499117     0.304348            NaN
# 2011-04-13 16:00:00          0.498592     0.360000       0.333333
# 2011-04-13 17:00:00          0.499416     0.324324            NaN
# 2011-04-13 18:00:00          0.498632     0.461538            NaN
# 2011-04-13 19:00:00          0.499415     0.285714            NaN
# ...

# %%
v = concat.pivot_table(
        index=['Source IP', 'Destination port'], 
         columns='Date/time', 
         values='Source port'
).reset_index()
v.index.name = v.columns.name = None
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-125-7c2ec9581449> in <module>
#       2         index=['Source IP', 'Destination port'],
#       3          columns='Date/time',
# ----> 4          values='Source port'
#       5 ).reset_index()
#       6 v.index.name = v.columns.name = None
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5757                            aggfunc=aggfunc, fill_value=fill_value,
#    5758                            margins=margins, dropna=dropna,
# -> 5759                            margins_name=margins_name)
#    5760
#    5761     def stack(self, level=-1, dropna=True):
#
# ...
